**kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\model.py:239, in Model.predict(self, source, stream, predictor, **kwargs)
#     237 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     238     self.predictor.set_prompts(prompts)
# --> 239 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# --> 198     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\utils\_contextlib.py:56, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      53         else:
#      54             # Pass the last request to the generator and get its response
#      55             with ctx_factory():
# ---> 56                 response = gen.send(request)
#      58 # We let the exceptions raised above by the generator's `.throw` or
#      59 # `.send` methods bubble up to our caller, except for StopIteration
#      60 except StopIteration as e:
#      61     # The generator informed us that it is done: take whatever its
#      62     # returned value (if any) was and indicate that we're done too
#      63     # by returning it (see docs for python's return-statement).
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:265, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     263 # Inference
#     264 with profilers[1]:
# --> 265     preds = self.inference(im, *args, **kwargs)
#     267 # Postprocess
#     268 with profilers[2]:
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:137, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     136                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 137 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\autobackend.py:347, in AutoBackend.forward(self, im, augment, visualize)
#     344     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     346 if self.pt or self.nn_module:  # PyTorch
# --> 347     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     348 elif self.jit:  # TorchScript
#     349     y = self.model(im)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\modules\head.py:59, in Detect.forward(self, x)
#      57 else:
#      58     box, cls = x_cat.split((self.reg_max * 4, self.nc), 1)
# ---> 59 dbox = dist2bbox(self.dfl(box), self.anchors.unsqueeze(0), xywh=True, dim=1) * self.strides
#      61 if self.export and self.format in ('tflite', 'edgetpu'):
#      62     # Normalize xywh with image size to mitigate quantization error of TFLite integer models as done in YOLOv5:
#      63     # https://github.com/ultralytics/yolov5/blob/0c8de3fca4a702f8ff5c435e67f378d1fce70243/models/tf.py#L307-L309
#      64     # See this PR for details: https://github.com/ultralytics/ultralytics/pull/1695
#      65     img_h = shape[2] * self.stride[0]
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\modules\block.py:33, in DFL.forward(self, x)
#      31 """Applies a transformer layer on input tensor 'x' and returns a tensor."""
#      32 b, c, a = x.shape  # batch, channels, anchors
# ---> 33 return self.conv(x.view(b, 4, self.c1, a).transpose(2, 1).softmax(1)).view(b, 4, a)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Streaming for-loop with tracking

import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = "Twitch\mortdog_gaming.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 257.9ms
# Speed: 9.8ms preprocess, 257.9ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 191.6ms
# Speed: 5.4ms preprocess, 191.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.5ms
# Speed: 0.0ms preprocess, 169.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 200.0ms
# Speed: 2.0ms preprocess, 200.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 187.4ms
# Speed: 8.0ms preprocess, 187.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 141.2ms
# Speed: 9.2ms preprocess, 141.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 187.6ms
# Speed: 3.5ms preprocess, 187.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.9ms
# Speed: 4.1ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.3ms
# Speed: 4.0ms preprocess, 177.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.4ms
# Speed: 3.2ms preprocess, 185.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 203.6ms
# Speed: 5.3ms preprocess, 203.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 194.8ms
# Speed: 0.0ms preprocess, 194.8ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.3ms
# Speed: 4.3ms preprocess, 182.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 144.6ms
# Speed: 4.2ms preprocess, 144.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 153.3ms
# Speed: 7.7ms preprocess, 153.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person,
a href='vscode-notebook-cell:/c%3A/Users/phamh/OneDrive/D/01.Projects/Yolov8/tracking.ipynb#W1sZmlsZQ%3D%3D?line=19'>20</a>     results = model.track(frame, persist=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/phamh/OneDrive/D/01.Projects/Yolov8/tracking.ipynb#W1sZmlsZQ%3D%3D?line=21'>22</a>     # Visualize the results on the frame
#      <a href='vscode-notebook-cell:/c%3A/Users/phamh/OneDrive/D/01.Projects/Yolov8/tracking.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a>     annotated_frame = results[0].plot()
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\model.py:259, in Model.track(self, source, stream, persist, **kwargs)
#     257 kwargs['conf'] = kwargs.get('conf') or 0.1  # ByteTrack-based method needs low confidence predictions as input
#     258 kwargs['mode'] = 'track'
# --> 259 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\model.py:239, in Model.predict(self, source, stream, predictor, **kwargs)
#     237 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     238     self.predictor.set_prompts(prompts)
# --> 239 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# --> 198     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:265, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     263 # Inference
#     264 with profilers[1]:
# --> 265     preds = self.inference(im, *args, **kwargs)
#     267 # Postprocess
#     268 with profilers[2]:
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\engine\predictor.py:137, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     136                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 137 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\autobackend.py:347, in AutoBackend.forward(self, im, augment, visualize)
#     344     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     346 if self.pt or self.nn_module:  # PyTorch
# --> 347     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     348 elif self.jit:  # TorchScript
#     349     y = self.model(im)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\ultralytics\nn\modules\conv.py:40, in Conv.forward_fuse(self, x)
#      38 def forward_fuse(self, x):
#      39     """Perform transposed convolution of 2D data."""
# ---> 40     return self.act(self.conv(x))
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\phamh\.conda\envs\yolov8\lib\site-packages\torch\nn\modules\conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
# Plotting tracks over time

from collections import defaultdict

import cv2
import numpy as np

from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Open the video file
video_path = "path/to/video.mp4"
cap = cv2.VideoCapture(video_path)

# Store the track history
track_history = defaultdict(lambda: [])

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Get the boxes and track IDs
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Plot the tracks
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point
            if len(track) > 30:  # retain 90 tracks for 90 frames
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

        # Display the annotated frame
        cv2.imshow("YOLOv8 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
